# %%
import datasets
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import SGDClassifier
#from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.metrics import confusion_matrix
import seaborn as sns
import math
import pandas as pd
from collections import Counter

feature_list = ['Summated_QRS_integral_V5',
 'S_Peak_Amplitude_C_V5',
 'S_Peak_Amplitude_C_V4',
 'R_Area_C_V5',
 'T_Peak_Amplitude_C_V2',
 'Q_Duration_C_II',
 'S_Area_C_V3',
 'Summated_QRS_integral_V3',
 'Summated_QRS_integral_V6',
 'Summated_QRS_integral_V4',
 'T_Area_C_V2',
 'Q_Peak_Amplitude_C_aVR',
 'Q_Area_C_V1',
 'S_Duration_C_V1',
 'S_Area_C_V4',
 'R_Duration_C_II',
 'R_Peak_Amplitude_C_V2',
 'P_Peak_Amplitude_C_aVR',
 'P_Peak_Amplitude_C_V3',]

feature_list_all_6 = ['Summated_QRS_integral_V5',
 'S_Peak_Amplitude_C_V5',
 'S_Peak_Amplitude_C_V4',
 'R_Area_C_V5',
 'T_Peak_Amplitude_C_V2',
 'Q_Duration_C_II',
 'S_Area_C_V3',
 'Summated_QRS_integral_V3',
 'Summated_QRS_integral_V6',
 'Summated_QRS_integral_V4',
 'T_Area_C_V2',
 'Q_Peak_Amplitude_C_aVR',
 'Q_Area_C_V1',
 'S_Duration_C_V1',
 'S_Area_C_V4',
 'R_Duration_C_II',
 'R_Peak_Amplitude_C_V2',
 'P_Peak_Amplitude_C_aVR',
 'P_Peak_Amplitude_C_V3',
 #'S_Peak_Amplitude_C_V3'
                     ]

feature_list1 = ['QRS_Duration__ms_C',
 'T_Axis_C',
 'QTc_Calculation_C',
 'QTc_Bazett_C',
 'QTc_Friderica_C',
 'T_Peak_Amplitude_C_II',
 'T_Area_C_II',
 'T_Peak_Amplitude_C_V1',
 'T_Area_C_V1',
 'T_Peak_Amplitude_C_V2',
 'T_Area_C_V2',
 'T_Peak_Amplitude_C_V3',
 'T_Area_C_V3',
 'T_Peak_Amplitude_C_V4',
 'T_Area_C_V4',
 'T_Peak_Amplitude_C_V5',
 'T_Area_C_V5',
 'T_Peak_Amplitude_C_V6',
 'T_Area_C_V6',]

names = [
    "Nearest Neighbors",
    "Linear SVM",
    "RBF SVM",
    "Neural Net",
    "AdaBoost",
]

classifiers = [
    KNeighborsClassifier(10),
    SVC(kernel="linear",probability=True),
    #SGDClassifier(loss='hinge', max_iter=1000, tol=1e-3, random_state=42),
    SVC(kernel="rbf",probability=True,C = 1.2),#nuSVM how many sup vectors
    #MLPClassifier(alpha=1, max_iter=500),
    MLPClassifier(hidden_layer_sizes=(10,), learning_rate="adaptive", verbose=True, activation="relu", solver="adam", alpha=10, max_iter=500),
    AdaBoostClassifier(estimator =DecisionTreeClassifier(max_depth=3),n_estimators=10),
]

# %%
def get_data(split: str,data_dir:str, silent: bool = False, cache_dir: str = None):
    print(f'Loading ECG dataset ({split} split) from Huggingface...')
    dataset = datasets.load_dataset('honggen-organization/ECG-disease-clf', split=split, data_dir=data_dir, cache_dir=cache_dir)
    print('done')
    return dataset

def binary_proprocess(disease_data, normal_data):
    disease_df = disease_data.data.to_pandas()#[feature_list_all_6]
    normal_df = normal_data.data.to_pandas()#[feature_list_all_6]
    #For the large dataset wpws, we can sample some patiens
    try:
        normal_df = normal_df[normal_df['Group'].isin(list(set(disease_df['Group'])))]#.sample(n=10000, random_state=42)
    except:
        normal_df = normal_df
    print(set(disease_df['Group']))
    print(set(normal_df['Group']))
    #disease_df = disease_df.drop('Group', axis=1)
    #normal_df = normal_df.drop('Group', axis=1)
    return disease_df,normal_df
#[feature_list_all_6][feature_list_all_6]

# %%
def clf(disease_df, health_df, test_disease, test_health, interation = 1, downsample = True, agument=False):
    accu_data = []
    conf_tn_data = []
    conf_fp_data = []
    conf_fn_data = []
    conf_tp_data = []
    disease_test = test_disease.values.tolist()
    h_test  = test_health.values.tolist()
    X_test = disease_test+h_test
    y_test1 = np.ones(len(disease_test))
    y_test2 = np.zeros(len(h_test))
    y_test = np.append(y_test1,y_test2)
    dic_acc = {}
    for i in range(interation):
        if agument:
            upsample_factor = math.floor(len(health_df) / len(disease_df))
            disease_sampled = disease_df.sample(len(health_df)-upsample_factor*len(disease_df), replace=True, random_state=40).reset_index(drop=True)
            disease_df = pd.concat([disease_df] * int(upsample_factor)).reset_index(drop=True)
            disease_df = pd.concat([disease_df,disease_sampled]).reset_index(drop=True)
            print(len(disease_df))
            
        if downsample:
            health_df= health_df.sample(n=len(disease_df), random_state=42).reset_index(drop=True)
        
        disease_X  = disease_df.values.tolist()
        h_X  = health_df.values.tolist()
        print(len(disease_X))
        print(len(h_X))

        X = disease_X+h_X
        y1 = np.ones(len(disease_X))
        y2 = np.zeros(len(h_X))
        y_train = np.append(y1,y2)
        X_train = np.array(X)
        scaler = StandardScaler().fit(X_train)
        X_train = scaler.transform(X_train)
        X_test = scaler.transform(np.array(X_test))
        Pred_len = len(y_test)

        conf_tn = {}
        conf_fp= {}
        conf_fn= {}
        conf_tp= {}
        dic_roc = {}
        for name, clf in zip(names, classifiers):
            clf.fit(X_train, y_train)
            y_pred = clf.predict(X_test)
            score = clf.score(X_test, y_test)
            y_prob = clf.predict_proba(X_test)
            tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
            #print(name)
            #print('y_test',y_test)
            #print('y_prob',y_prob[:,1])
            
            df = pd.DataFrame(list(zip(y_test, y_prob[:,1])), columns = ['test', 'prob'])
            dic_roc[name] =df
            dic_acc[name] = score
            conf_tn[name] = tn/(tn+fp)
            conf_tp[name] = tp/(tp+fn)
        accu_data.append(dic_acc)
        conf_tn_data.append(conf_tn)
        conf_tp_data.append(conf_tp)
    df_accu_data =pd.DataFrame.from_dict(accu_data)
    print('Accuracy: \n', df_accu_data.mean())
    df_conf_tn_data = pd.DataFrame.from_dict(conf_tn_data)
    df_conf_tp_data = pd.DataFrame.from_dict(conf_tp_data)
    print('-----------------')
    print('True_negative: \n', df_conf_tn_data.mean())
    print('-----------------')
    print('True_Positive: \n', df_conf_tp_data.mean())
    return dic_roc,df_conf_tp_data,df_conf_tn_data

# %%
data_method = 'augment'
data = 'kd'
augment = True
downsample = False

normal_data_train = get_data(split= 'train', data_dir = 'normal', cache_dir = './cache/huggingface/datasets')
normal_data_test = get_data(split= 'test', data_dir = 'normal', cache_dir = './cache/huggingface/datasets')

tpr_all = np.zeros((5,5))
tnr_all = np.zeros((5,5))
for i in range(1,6):
    kd_data_train = get_data(split= 'train', data_dir = f"{data}/data{i}", cache_dir = './cache/huggingface/datasets')
    kd_data_test = get_data(split= 'test', data_dir = f"{data}/data{i}", cache_dir = './cache/huggingface/datasets')
    disease_train, normal_train = binary_proprocess(kd_data_train, normal_data_train)
    disease_test, normal_test = binary_proprocess(kd_data_test, normal_data_test)
    disease_test = disease_test[disease_test['Group'] == 6]
    normal_test = normal_test[normal_test['Group'] == 6]

    disease_train = disease_train[feature_list1]
    normal_train = normal_train[feature_list1]
    disease_test = disease_test[feature_list1]
    normal_test = normal_test[feature_list1]

    
    df_dic,df_tpr,df_tnr = clf(disease_df = disease_train, health_df =normal_train,
                                    test_disease = disease_test, test_health = normal_test, 
                                    interation = 1,downsample = downsample,agument=augment)
    for name in names:
        df_dic[name].to_csv(f"./{data}_roc20/{data_method}/{name}_clinical_roc{i}.csv", index=False)
    tpr_all[i-1,:] = df_tpr.values
    tnr_all[i-1,:] = df_tnr.values
    
    
#df_tnr = pd.DataFrame(tnr_all, columns = names)
#df_tnr.to_csv(f"./{data}_roc/{data_method}/tnr.csv", index=False)
#df_tpr = pd.DataFrame(tpr_all, columns = names)
#df_tpr.to_csv(f"./{data}_roc/{data_method}/tpr.csv", index=False)
# Out:
# Loading ECG dataset (train split) from Huggingface...
# done
# Loading ECG dataset (test split) from Huggingface...
# done
# Loading ECG dataset (train split) from Huggingface...
# done
# Loading ECG dataset (test split) from Huggingface...
# done
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# 5777
# 5777
# 5777
# Iteration 1, loss = 1.45636660
# Iteration 2, loss = 1.10098763
# Iteration 3, loss = 0.92667496
# Iteration 4, loss = 0.83153238
# Iteration 5, loss = 0.77255910
# Iteration 6, loss = 0.73136095
# Iteration 7, loss = 0.70092196
# Iteration 8, loss = 0.67760562
# Iteration 9, loss = 0.65943527
# Iteration 10, loss = 0.64525371
# Iteration 11, loss = 0.63415023
# Iteration 12, loss = 0.62570683
# Iteration 13, loss = 0.61864253
# Iteration 14, loss = 0.61280244
# Iteration 15, loss = 0.60804153
# Iteration 16, loss = 0.60390421
# Iteration 17, loss = 0.60076293
# Iteration 18, loss = 0.59822901
# Iteration 19, loss = 0.59638760
# Iteration 20, loss = 0.59445165
# Iteration 21, loss = 0.59325443
# Iteration 22, loss = 0.59197748
# Iteration 23, loss = 0.59121047
# Iteration 24, loss = 0.59056653
# Iteration 25, loss = 0.59005443
# Iteration 26, loss = 0.58937473
# Iteration 27, loss = 0.58901784
# Iteration 28, loss = 0.58880412
# Iteration 29, loss = 0.58839339
# Iteration 30, loss = 0.58820818
# Iteration 31, loss = 0.58792125
# Iteration 32, loss = 0.58779628
# Iteration 33, loss = 0.58759593
# Iteration 34, loss = 0.58739621
# Iteration 35, loss = 0.58743457
# Iteration 36, loss = 0.58716527
# Iteration 37, loss = 0.58703940
# Iteration 38, loss = 0.58691674
# Iteration 39, loss = 0.58698605
# Iteration 40, loss = 0.58674247
# Iteration 41, loss = 0.58680284
# Iteration 42, loss = 0.58669997
# Iteration 43, loss = 0.58646994
# Iteration 44, loss = 0.58641541
# Iteration 45, loss = 0.58658589
# Iteration 46, loss = 0.58647186
# Iteration 47, loss = 0.58645334
# Iteration 48, loss = 0.58637544
# Iteration 49, loss = 0.58645768
# Iteration 50, loss = 0.58618309
# Iteration 51, loss = 0.58611437
# Iteration 52, loss = 0.58613829
# Iteration 53, loss = 0.58618814
# Iteration 54, loss = 0.58635728
# Iteration 55, loss = 0.58635797
# Iteration 56, loss = 0.58609260
# Iteration 57, loss = 0.58639025
# Iteration 58, loss = 0.58613346
# Iteration 59, loss = 0.58603759
# Iteration 60, loss = 0.58616373
# Iteration 61, loss = 0.58608223
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# /home/honggen/.local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy:
#  Nearest Neighbors    0.821053
# Linear SVM           0.673684
# RBF SVM              0.742105
# Neural Net           0.673684
# AdaBoost             0.757895
# dtype: float64
# -----------------
# True_negative:
#  Nearest Neighbors    0.829412
# Linear SVM           0.647059
# RBF SVM              0.752941
# Neural Net           0.652941
# AdaBoost             0.747059
# dtype: float64
# -----------------
# True_Positive:
#  Nearest Neighbors    0.75
# Linear SVM           0.90
# RBF SVM              0.65
# Neural Net           0.85
# AdaBoost             0.85
# dtype: float64
# Loading ECG dataset (train split) from Huggingface...
# done
# Loading ECG dataset (test split) from Huggingface...
# done
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# 5777
# 5777
# 5777
# Iteration 1, loss = 1.11718608
# Iteration 2, loss = 0.93865005
# Iteration 3, loss = 0.83792233
# Iteration 4, loss = 0.76818775
# Iteration 5, loss = 0.72042913
# Iteration 6, loss = 0.68586393
# Iteration 7, loss = 0.65994196
# Iteration 8, loss = 0.64034616
# Iteration 9, loss = 0.62568879
# Iteration 10, loss = 0.61460281
# Iteration 11, loss = 0.60552937
# Iteration 12, loss = 0.59841703
# Iteration 13, loss = 0.59262686
# Iteration 14, loss = 0.58789221
# Iteration 15, loss = 0.58440712
# Iteration 16, loss = 0.58201757
# Iteration 17, loss = 0.58014476
# Iteration 18, loss = 0.57870042
# Iteration 19, loss = 0.57731290
# Iteration 20, loss = 0.57649587
# Iteration 21, loss = 0.57568795
# Iteration 22, loss = 0.57507530
# Iteration 23, loss = 0.57489617
# Iteration 24, loss = 0.57419684
# Iteration 25, loss = 0.57390609
# Iteration 26, loss = 0.57381462
# Iteration 27, loss = 0.57331859
# Iteration 28, loss = 0.57319433
# Iteration 29, loss = 0.57313413
# Iteration 30, loss = 0.57279307
# Iteration 31, loss = 0.57261475
# Iteration 32, loss = 0.57237004
# Iteration 33, loss = 0.57242585
# Iteration 34, loss = 0.57227955
# Iteration 35, loss = 0.57194733
# Iteration 36, loss = 0.57227479
# Iteration 37, loss = 0.57209725
# Iteration 38, loss = 0.57203190
# Iteration 39, loss = 0.57204314
# Iteration 40, loss = 0.57177795
# Iteration 41, loss = 0.57171850
# Iteration 42, loss = 0.57180683
# Iteration 43, loss = 0.57166611
# Iteration 44, loss = 0.57187624
# Iteration 45, loss = 0.57193352
# Iteration 46, loss = 0.57151147
# Iteration 47, loss = 0.57161309
# Iteration 48, loss = 0.57155813
# Iteration 49, loss = 0.57142403
# Iteration 50, loss = 0.57130520
# Iteration 51, loss = 0.57113938
# Iteration 52, loss = 0.57154010
# Iteration 53, loss = 0.57161123
# Iteration 54, loss = 0.57117882
# Iteration 55, loss = 0.57126648
# Iteration 56, loss = 0.57114183
# Iteration 57, loss = 0.57105613
# Iteration 58, loss = 0.57107877
# Iteration 59, loss = 0.57133737
# Iteration 60, loss = 0.57116557
# Iteration 61, loss = 0.57116301
# Iteration 62, loss = 0.57089734
# Iteration 63, loss = 0.57103987
# Iteration 64, loss = 0.57085937
# Iteration 65, loss = 0.57077147
# Iteration 66, loss = 0.57077762
# Iteration 67, loss = 0.57073430
# Iteration 68, loss = 0.57042905
# Iteration 69, loss = 0.57043481
# Iteration 70, loss = 0.57056640
# Iteration 71, loss = 0.57039164
# Iteration 72, loss = 0.57021521
# Iteration 73, loss = 0.57037970
# Iteration 74, loss = 0.57010236
# Iteration 75, loss = 0.57012635
# Iteration 76, loss = 0.57018316
# Iteration 77, loss = 0.57014225
# Iteration 78, loss = 0.57022670
# Iteration 79, loss = 0.57004250
# Iteration 80, loss = 0.57010525
# Iteration 81, loss = 0.57034314
# Iteration 82, loss = 0.57024615
# Iteration 83, loss = 0.57008701
# Iteration 84, loss = 0.57014099
# Iteration 85, loss = 0.57008846
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# /home/honggen/.local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy:
#  Nearest Neighbors    0.788360
# Linear SVM           0.629630
# RBF SVM              0.724868
# Neural Net           0.666667
# AdaBoost             0.751323
# dtype: float64
# -----------------
# True_negative:
#  Nearest Neighbors    0.800000
# Linear SVM           0.605882
# RBF SVM              0.723529
# Neural Net           0.652941
# AdaBoost             0.758824
# dtype: float64
# -----------------
# True_Positive:
#  Nearest Neighbors    0.684211
# Linear SVM           0.842105
# RBF SVM              0.736842
# Neural Net           0.789474
# AdaBoost             0.684211
# dtype: float64
# Loading ECG dataset (train split) from Huggingface...
# done
# Loading ECG dataset (test split) from Huggingface...
# done
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# 5777
# 5777
# 5777
# Iteration 1, loss = 1.32233770
# Iteration 2, loss = 1.05022404
# Iteration 3, loss = 0.91671935
# Iteration 4, loss = 0.83442671
# Iteration 5, loss = 0.77602294
# Iteration 6, loss = 0.73223347
# Iteration 7, loss = 0.69840931
# Iteration 8, loss = 0.67130875
# Iteration 9, loss = 0.65074812
# Iteration 10, loss = 0.63522823
# Iteration 11, loss = 0.62365954
# Iteration 12, loss = 0.61508940
# Iteration 13, loss = 0.60880457
# Iteration 14, loss = 0.60406074
# Iteration 15, loss = 0.60048391
# Iteration 16, loss = 0.59793838
# Iteration 17, loss = 0.59589253
# Iteration 18, loss = 0.59413236
# Iteration 19, loss = 0.59284480
# Iteration 20, loss = 0.59189530
# Iteration 21, loss = 0.59104170
# Iteration 22, loss = 0.59042137
# Iteration 23, loss = 0.58992843
# Iteration 24, loss = 0.58939035
# Iteration 25, loss = 0.58905966
# Iteration 26, loss = 0.58873167
# Iteration 27, loss = 0.58831533
# Iteration 28, loss = 0.58786112
# Iteration 29, loss = 0.58732245
# Iteration 30, loss = 0.58725149
# Iteration 31, loss = 0.58700691
# Iteration 32, loss = 0.58673530
# Iteration 33, loss = 0.58644992
# Iteration 34, loss = 0.58629158
# Iteration 35, loss = 0.58599550
# Iteration 36, loss = 0.58598744
# Iteration 37, loss = 0.58589899
# Iteration 38, loss = 0.58575214
# Iteration 39, loss = 0.58553740
# Iteration 40, loss = 0.58537303
# Iteration 41, loss = 0.58539244
# Iteration 42, loss = 0.58505371
# Iteration 43, loss = 0.58489874
# Iteration 44, loss = 0.58481943
# Iteration 45, loss = 0.58497417
# Iteration 46, loss = 0.58467243
# Iteration 47, loss = 0.58487392
# Iteration 48, loss = 0.58464755
# Iteration 49, loss = 0.58461932
# Iteration 50, loss = 0.58467918
# Iteration 51, loss = 0.58445991
# Iteration 52, loss = 0.58428361
# Iteration 53, loss = 0.58428006
# Iteration 54, loss = 0.58418239
# Iteration 55, loss = 0.58405436
# Iteration 56, loss = 0.58430990
# Iteration 57, loss = 0.58416462
# Iteration 58, loss = 0.58405478
# Iteration 59, loss = 0.58404574
# Iteration 60, loss = 0.58401740
# Iteration 61, loss = 0.58397389
# Iteration 62, loss = 0.58405041
# Iteration 63, loss = 0.58401753
# Iteration 64, loss = 0.58387867
# Iteration 65, loss = 0.58387234
# Iteration 66, loss = 0.58381376
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# /home/honggen/.local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy:
#  Nearest Neighbors    0.784211
# Linear SVM           0.668421
# RBF SVM              0.763158
# Neural Net           0.689474
# AdaBoost             0.778947
# dtype: float64
# -----------------
# True_negative:
#  Nearest Neighbors    0.829412
# Linear SVM           0.647059
# RBF SVM              0.770588
# Neural Net           0.664706
# AdaBoost             0.794118
# dtype: float64
# -----------------
# True_Positive:
#  Nearest Neighbors    0.40
# Linear SVM           0.85
# RBF SVM              0.70
# Neural Net           0.90
# AdaBoost             0.65
# dtype: float64
# Loading ECG dataset (train split) from Huggingface...
# done
# Loading ECG dataset (test split) from Huggingface...
# done
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# 5777
# 5777
# 5777
# Iteration 1, loss = 1.05280361
# Iteration 2, loss = 0.91011306
# Iteration 3, loss = 0.82549597
# Iteration 4, loss = 0.76508508
# Iteration 5, loss = 0.71848689
# Iteration 6, loss = 0.68202895
# Iteration 7, loss = 0.65394816
# Iteration 8, loss = 0.63303973
# Iteration 9, loss = 0.61784745
# Iteration 10, loss = 0.60707557
# Iteration 11, loss = 0.59976408
# Iteration 12, loss = 0.59446381
# Iteration 13, loss = 0.59091645
# Iteration 14, loss = 0.58830661
# Iteration 15, loss = 0.58637470
# Iteration 16, loss = 0.58482871
# Iteration 17, loss = 0.58372566
# Iteration 18, loss = 0.58271960
# Iteration 19, loss = 0.58217544
# Iteration 20, loss = 0.58169809
# Iteration 21, loss = 0.58136768
# Iteration 22, loss = 0.58118965
# Iteration 23, loss = 0.58080305
# Iteration 24, loss = 0.58075557
# Iteration 25, loss = 0.58092830
# Iteration 26, loss = 0.58044532
# Iteration 27, loss = 0.58048031
# Iteration 28, loss = 0.58030049
# Iteration 29, loss = 0.58026249
# Iteration 30, loss = 0.58018339
# Iteration 31, loss = 0.58028250
# Iteration 32, loss = 0.58004497
# Iteration 33, loss = 0.58021590
# Iteration 34, loss = 0.58001047
# Iteration 35, loss = 0.57998208
# Iteration 36, loss = 0.58005320
# Iteration 37, loss = 0.57996059
# Iteration 38, loss = 0.57999968
# Iteration 39, loss = 0.57987261
# Iteration 40, loss = 0.57988432
# Iteration 41, loss = 0.57989978
# Iteration 42, loss = 0.57972611
# Iteration 43, loss = 0.57986604
# Iteration 44, loss = 0.57979498
# Iteration 45, loss = 0.57982986
# Iteration 46, loss = 0.57967817
# Iteration 47, loss = 0.57962713
# Iteration 48, loss = 0.57978820
# Iteration 49, loss = 0.57961006
# Iteration 50, loss = 0.57978644
# Iteration 51, loss = 0.57958339
# Iteration 52, loss = 0.57956987
# Iteration 53, loss = 0.57965823
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# /home/honggen/.local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy:
#  Nearest Neighbors    0.800000
# Linear SVM           0.668421
# RBF SVM              0.763158
# Neural Net           0.678947
# AdaBoost             0.747368
# dtype: float64
# -----------------
# True_negative:
#  Nearest Neighbors    0.829412
# Linear SVM           0.641176
# RBF SVM              0.776471
# Neural Net           0.658824
# AdaBoost             0.758824
# dtype: float64
# -----------------
# True_Positive:
#  Nearest Neighbors    0.55
# Linear SVM           0.90
# RBF SVM              0.65
# Neural Net           0.85
# AdaBoost             0.65
# dtype: float64
# Loading ECG dataset (train split) from Huggingface...
# done
# Loading ECG dataset (test split) from Huggingface...
# done
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# {4.0, 5.0, 6.0, 7.0, 8.0, 11.0, 12.0, 13.0, 14.0}
# 5777
# 5777
# 5777
# Iteration 1, loss = 1.12491485
# Iteration 2, loss = 0.93201301
# Iteration 3, loss = 0.84016747
# Iteration 4, loss = 0.77564035
# Iteration 5, loss = 0.72658987
# Iteration 6, loss = 0.68994954
# Iteration 7, loss = 0.66265676
# Iteration 8, loss = 0.64241319
# Iteration 9, loss = 0.62746001
# Iteration 10, loss = 0.61625750
# Iteration 11, loss = 0.60782781
# Iteration 12, loss = 0.60153203
# Iteration 13, loss = 0.59682170
# Iteration 14, loss = 0.59338789
# Iteration 15, loss = 0.59064101
# Iteration 16, loss = 0.58883560
# Iteration 17, loss = 0.58742313
# Iteration 18, loss = 0.58623661
# Iteration 19, loss = 0.58548737
# Iteration 20, loss = 0.58483613
# Iteration 21, loss = 0.58462413
# Iteration 22, loss = 0.58425112
# Iteration 23, loss = 0.58376709
# Iteration 24, loss = 0.58370811
# Iteration 25, loss = 0.58371175
# Iteration 26, loss = 0.58341551
# Iteration 27, loss = 0.58325053
# Iteration 28, loss = 0.58337128
# Iteration 29, loss = 0.58318633
# Iteration 30, loss = 0.58317665
# Iteration 31, loss = 0.58321198
# Iteration 32, loss = 0.58313952
# Iteration 33, loss = 0.58319153
# Iteration 34, loss = 0.58315866
# Iteration 35, loss = 0.58307145
# Iteration 36, loss = 0.58297068
# Iteration 37, loss = 0.58297175
# Iteration 38, loss = 0.58307394
# Iteration 39, loss = 0.58300313
# Iteration 40, loss = 0.58297252
# Iteration 41, loss = 0.58286399
# Iteration 42, loss = 0.58287935
# Iteration 43, loss = 0.58278319
# Iteration 44, loss = 0.58280907
# Iteration 45, loss = 0.58263421
# Iteration 46, loss = 0.58256126
# Iteration 47, loss = 0.58269606
# Iteration 48, loss = 0.58257783
# Iteration 49, loss = 0.58250670
# Iteration 50, loss = 0.58254428
# Iteration 51, loss = 0.58252759
# Iteration 52, loss = 0.58243761
# Iteration 53, loss = 0.58235773
# Iteration 54, loss = 0.58237621
# Iteration 55, loss = 0.58256954
# Iteration 56, loss = 0.58242116
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# /home/honggen/.local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy:
#  Nearest Neighbors    0.786096
# Linear SVM           0.673797
# RBF SVM              0.754011
# Neural Net           0.652406
# AdaBoost             0.780749
# dtype: float64
# -----------------
# True_negative:
#  Nearest Neighbors    0.805882
# Linear SVM           0.652941
# RBF SVM              0.752941
# Neural Net           0.623529
# AdaBoost             0.811765
# dtype: float64
# -----------------
# True_Positive:
#  Nearest Neighbors    0.588235
# Linear SVM           0.882353
# RBF SVM              0.764706
# Neural Net           0.941176
# AdaBoost             0.470588
# dtype: float64
